# %%
import pandas as pd
import xlrd

# %%
df = pd.read_excel('../../../data/lab/MENSAL_MUNICIPIOS-DESDE_Jan2013.xlsx')

# %%
df = df.dropna()
df = df.reset_index(drop=True)

# %%
df.columns = df.iloc[0].values
df = df.drop([0], axis=0)

# %%
df.head()
# Out:
#                    MÊS      PRODUTO        REGIÃO      ESTADO  \
# 1  2013-01-01 00:00:00  ÓLEO DIESEL         NORTE        PARA
# 2  2013-01-01 00:00:00  ÓLEO DIESEL      NORDESTE    MARANHAO
# 3  2013-01-01 00:00:00  ÓLEO DIESEL       SUDESTE   SAO PAULO
# 4  2013-01-01 00:00:00  ÓLEO DIESEL      NORDESTE  PERNAMBUCO
# 5  2013-01-01 00:00:00  ÓLEO DIESEL  CENTRO OESTE       GOIAS
#
#                MUNICÍPIO NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 1             ABAETETUBA                           40              R$/l
# 2             ACAILANDIA                           32              R$/l
# 3             ADAMANTINA                           35              R$/l
# 4  AFOGADOS DA INGAZEIRA                           20              R$/l
# 5  AGUAS LINDAS DE GOIAS                           20              R$/l
#
#   PREÇO MÉDIO REVENDA DESVIO PADRÃO REVENDA PREÇO MÍNIMO REVENDA  \
# 1               2.254                 0.069                 2.15
# ...

# %%
df.tail()
# Out:
#                         MÊS PRODUTO   REGIÃO          ESTADO      MUNICÍPIO  \
# 222953  2020-02-01 00:00:00     GNV  SUDESTE    MINAS GERAIS            UBA
# 222954  2020-02-01 00:00:00     GNV  SUDESTE       SAO PAULO       VALINHOS
# 222955  2020-02-01 00:00:00     GNV  SUDESTE  ESPIRITO SANTO     VILA VELHA
# 222956  2020-02-01 00:00:00     GNV  SUDESTE  ESPIRITO SANTO        VITORIA
# 222957  2020-02-01 00:00:00     GNV  SUDESTE  RIO DE JANEIRO  VOLTA REDONDA
#
#        NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA PREÇO MÉDIO REVENDA  \
# 222953                            1             R$/m3               3.695
# 222954                            4             R$/m3               3.174
# 222955                            4             R$/m3               3.299
# 222956                           16             R$/m3               3.274
# 222957                            6             R$/m3               3.786
#
# ...

# %%
mask = df['MUNICÍPIO'] == 'FORTALEZA'
df = df.loc[mask]

# %%
mask = df['PRODUTO'] == 'GASOLINA COMUM'
df = df.loc[mask]

# %%
df.head()
# Out:
#                        MÊS         PRODUTO    REGIÃO ESTADO  MUNICÍPIO  \
# 1709   2013-01-01 00:00:00  GASOLINA COMUM  NORDESTE  CEARA  FORTALEZA
# 4529   2013-02-01 00:00:00  GASOLINA COMUM  NORDESTE  CEARA  FORTALEZA
# 7373   2013-03-01 00:00:00  GASOLINA COMUM  NORDESTE  CEARA  FORTALEZA
# 10236  2013-04-01 00:00:00  GASOLINA COMUM  NORDESTE  CEARA  FORTALEZA
# 13104  2013-05-01 00:00:00  GASOLINA COMUM  NORDESTE  CEARA  FORTALEZA
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA PREÇO MÉDIO REVENDA  \
# 1709                           293              R$/l               2.675
# 4529                           292              R$/l                2.85
# 7373                           292              R$/l               2.847
# 10236                          292              R$/l               2.793
# 13104                          365              R$/l               2.722
#
#       DESVIO PADRÃO REVENDA PREÇO MÍNIMO REVENDA PREÇO MÁXIMO REVENDA  \
# ...

# %%
df.tail(38)
# Out:
#                         MÊS         PRODUTO    REGIÃO ESTADO  MUNICÍPIO  \
# 132077  2017-01-01 00:00:00  GASOLINA COMUM  NORDESTE  CEARA  FORTALEZA
# 134696  2017-02-01 00:00:00  GASOLINA COMUM  NORDESTE  CEARA  FORTALEZA
# 137310  2017-03-01 00:00:00  GASOLINA COMUM  NORDESTE  CEARA  FORTALEZA
# 139924  2017-04-01 00:00:00  GASOLINA COMUM  NORDESTE  CEARA  FORTALEZA
# 142534  2017-05-01 00:00:00  GASOLINA COMUM  NORDESTE  CEARA  FORTALEZA
# 145143  2017-06-01 00:00:00  GASOLINA COMUM  NORDESTE  CEARA  FORTALEZA
# 147747  2017-07-01 00:00:00  GASOLINA COMUM  NORDESTE  CEARA  FORTALEZA
# 150220  2017-08-01 00:00:00  GASOLINA COMUM  NORDESTE  CEARA  FORTALEZA
# 152612  2017-09-01 00:00:00  GASOLINA COMUM  NORDESTE  CEARA  FORTALEZA
# 155000  2017-10-01 00:00:00  GASOLINA COMUM  NORDESTE  CEARA  FORTALEZA
# 157392  2017-11-01 00:00:00  GASOLINA COMUM  NORDESTE  CEARA  FORTALEZA
# 159782  2017-12-01 00:00:00  GASOLINA COMUM  NORDESTE  CEARA  FORTALEZA
# ...

# %%
df = df.tail(38)

# %%
df = df.drop(['PRODUTO', 'REGIÃO', 'ESTADO', 'MUNICÍPIO', 
              'NÚMERO DE POSTOS PESQUISADOS', 'UNIDADE DE MEDIDA',
              'MARGEM MÉDIA REVENDA', 'COEF DE VARIAÇÃO REVENDA',
              'COEF DE VARIAÇÃO DISTRIBUIÇÃO'], axis=1)

# %%
df.index = range(0, len(df))
df.head()
# Out:
#                    MÊS PREÇO MÉDIO REVENDA DESVIO PADRÃO REVENDA  \
# 0  2017-01-01 00:00:00                3.98                 0.015
# 1  2017-02-01 00:00:00               3.974                 0.021
# 2  2017-03-01 00:00:00               3.822                 0.098
# 3  2017-04-01 00:00:00               3.591                 0.126
# 4  2017-05-01 00:00:00               3.876                 0.023
#
#   PREÇO MÍNIMO REVENDA PREÇO MÁXIMO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 3.89                3.999                    3.492
# 1                3.859                3.999                    3.525
# 2                3.459                3.999                    3.449
# 3                 3.44                 3.89                    3.385
# 4                3.779                 3.99                    3.445
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                      0.043                     3.349
# ...

# %%
df.tail()
# Out:
#                     MÊS PREÇO MÉDIO REVENDA DESVIO PADRÃO REVENDA  \
# 33  2019-10-01 00:00:00               4.572                 0.109
# 34  2019-11-01 00:00:00               4.375                 0.125
# 35  2019-12-01 00:00:00               4.644                 0.096
# 36  2020-01-01 00:00:00               4.679                 0.025
# 37  2020-02-01 00:00:00               4.657                  0.04
#
#    PREÇO MÍNIMO REVENDA PREÇO MÁXIMO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 33                 4.19                 4.89                      4.1
# 34                 4.15                4.699                    4.079
# 35                 4.19                4.799                    4.187
# 36                 4.39                4.799                     4.22
# 37                4.539                 4.89                    4.135
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 33                      0.057                     3.789
# ...

# %%
df.to_csv('../../../data/miner/gasolina_fortaleza17-20.csv')
