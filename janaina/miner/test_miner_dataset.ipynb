# %%
import pandas as pd
import numpy as np
import function_miner_dataset_date as mds

from datetime import date
import holidays

# %%
from importlib import reload
reload(mds)
# Out:
# <module 'function_miner_dataset_date' from '/home/personal-arthur/Documentos/Dev.Academy/andromeda/src/quixada/miner/function_miner_dataset_date.py'>

# %%
path_miner  = '../../../data/miner/'
path_res    = '../../../data/res/'

id_ass      = '09517617000153'
id_loja     = '3'

data        = '09517617000153_3.csv'

idProd  = '128568'

# %%
df = mds.is_var_holliday(id_ass=id_ass, id_loja=id_loja, id_prod=841984981981)
# Out:
# Produto não existente

# %%
df = mds.is_var_holliday(id_ass=id_ass, id_loja=id_loja, id_prod=idProd)

# %%
df.head()
# Out:
#                  data  produtoId                           descr    valor  \
# data
# 2019-01-02 2019-01-02     128568  CERVEJA DEVASSA LOURA 350ML LT   172.08
# 2019-01-03 2019-01-03     128568  CERVEJA DEVASSA LOURA 350ML LT    31.07
# 2019-01-04 2019-01-04     128568  CERVEJA DEVASSA LOURA 350ML LT   411.08
# 2019-01-05 2019-01-05     128568  CERVEJA DEVASSA LOURA 350ML LT  1978.92
# 2019-01-06 2019-01-06     128568  CERVEJA DEVASSA LOURA 350ML LT   358.50
#
#             quantidade  valorCancelado  quantidadeCancelada  \
# data
# 2019-01-02        72.0           21.51                  9.0
# 2019-01-03        13.0            0.00                  0.0
# 2019-01-04       172.0            0.00                  0.0
# 2019-01-05       828.0          260.51                109.0
# 2019-01-06       150.0            0.00                  0.0
#
#             quantidadeDocumentos  quantidadeValorZero  sense_Carnaval  \
# data
# ...

# %%
df = mds.miner_dataset_date(id_ass=id_ass, id_loja=id_loja, id_prod='984654654')
# Out:
# Produto não existente

# %%
df = mds.miner_dataset_date(id_ass=id_ass, id_loja=id_loja, id_prod=idProd)

# %%
df.head()
# Out:
#    quantidade  valor_unit   ano  mes  dia_semana  dia  fim_semana  inicio_mes  \
# 0        72.0        2.29  2019    1           2    2           0           1
# 1        13.0        2.29  2019    1           3    3           0           1
# 2       172.0        2.29  2019    1           4    4           0           1
# 3       828.0        2.29  2019    1           5    5           1           1
# 4       150.0        2.29  2019    1           6    6           1           1
#
#    feriado
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
df = mds.miner_dataset_date_sense(id_ass=id_ass, id_loja=id_loja, id_prod=984654654)
# Out:
# Produto não existente

# %%
df = mds.miner_dataset_date_sense(id_ass=id_ass, id_loja=id_loja, id_prod=idProd)

# %%
df.head()
# Out:
#    quantidade  sense_Carnaval  sense_SemanaSanta  sense_Natal  sense_AnoNovo  \
# 0        72.0               1                  0            1              1
# 1        13.0               1                  0            1              1
# 2       172.0               1                  0            1              1
# 3       828.0               1                  0            1              1
# 4       150.0               1                  0            1              1
#
#    valor_unit   ano  mes  dia_semana  dia  fim_semana  inicio_mes  feriado
# 0        2.29  2019    1           2    2           0           1        0
# 1        2.29  2019    1           3    3           0           1        0
# 2        2.29  2019    1           4    4           0           1        0
# 3        2.29  2019    1           5    5           1           1        0
# 4        2.29  2019    1           6    6           1           1        0
